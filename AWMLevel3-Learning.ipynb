# %% [markdown]
# ## Importing libraries
#
# We import basic libraries and modules for our simulation

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import gym
import agentwebmodel

#from stable_baselines3.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C

from IPython.display import display
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Setting up the model
#
# We set up our environment and instantiate an agent.

# %%
gym_env = gym.make('awm_level3-v1')

env = DummyVecEnv([lambda: gym_env])
modelA2C = A2C('MlpPolicy', env, verbose=1,tensorboard_log="./logs/")

# %% [markdown]
# ## Training the agent
#
# We train the agent over $10^6$ timesteps.

# %%
modelA2C.learn(total_timesteps=10**6)
# Out:
# WARNING:tensorflow:From /home/fmzennaro/miniconda2_1/envs/quantumgymstable/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1035: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 16        |
# | nupdates           | 1         |
# | policy_entropy     | 5.99      |
# | total_timesteps    | 5         |
# | value_loss         | 12.4      |
# ----------------------------------
# WARNING:tensorflow:From /home/fmzennaro/miniconda2_1/envs/quantumgymstable/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:581: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 751      |
# | nupdates           | 100      |
# | policy_entropy     | 5.99     |
# | total_timesteps    | 500      |
# ...
